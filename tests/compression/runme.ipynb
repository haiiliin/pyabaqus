# %% [markdown]
# # Compression model

# %% [markdown]
# ## Create model

# %%
import abaqus

abaqus.runPythonScript('compression.py')

# %% [markdown]
# ## Submit job

# %%
import abaqus

abaqus.submitJobByInputFile('Job-1.inp')

# %% [markdown]
# ## Extract output data

# %%
import abaqus

abaqus.extractOutputData('Job-1.odb', 'compression-output.py')

# %% [markdown]
# ## Draw figure

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data.csv')
plt.plot(data.time, data.U3)
plt.grid()
plt.xlabel('Time')
plt.ylabel('Displacement')
plt.savefig('compression.png', dpi=600, bbox_inches='tight', pad_inches=0)
plt.show()
